# %%
# %load_ext autoreload
# %autoreload 2

import qc_utils as utils
import cirq
from cirq.contrib.svg import SVGCircuit
import matplotlib.pyplot as plt
import sympy
import itertools
import numpy as np

# %% [markdown]
# # Forward

# %% [markdown]
# # The portfolio rebalancing optimization problem

# %% [markdown]
# Suppose there are $N$ risky assets that have a mean return $\mu_k$ and a volatility $\sigma_k$. There is a vector ${\bf z} = [z_1, ..., z_n]$, where $z_k = \lbrace -1,0,1 \rbrace $ that represents our current holdings. A value of $+1 (-1)$ indicates that we currently hold (short) the $k$-th asset and a value of $0$ indicates that we do not take any position for that asset.
#
# The optimal portfolio is the one that minimizes the return-risk cost function $C_{RR}({\bf z})$ given by
#
# $$
# C_{RR}({\bf z}) = -\sum_k (1-\lambda) r_k z_k + \lambda\sum_{kj} \sigma_{kj} z_k z_j,
# $$
#
#
# where $0 \leq \lambda \leq 1$ represents an asset manager control parameter that balances the return-risk trade-off, $\lambda=0$ favours returns and $\lambda = 1$ favours the risk.

# %% [markdown]
# ## The trading costs

# %% [markdown]
# The change of the vector ${\bf z}$ incuurs trading fees. Those amount of fees that this change genertes will be given contained in the trading-cost function
#
# $$
# C_{TC}({\bf z}) = \sum_j (1-\delta(z_i-y_i))T,
# $$
#
#
# where the vector ${\bf y}$ represents the previous positions of the portfolio, $T$ is the transaction fee and $\delta$ is the discrete Kronecker delta function.

# %% [markdown]
# ## Trading constraints

# %% [markdown]
# The above problem should be solved under the condition that we have a discrete number of assets to be invested
#
# $$
# \sum_j z_j =D
# $$

# %% [markdown]
# # Function encoding

# %% [markdown]
# The variable $z_j = \lbrace -1,0,1\rbrace$ is encoded as a difference of two spin variables
# as
#
# $$
# z_j = \frac{1}{2}\left( s^+_j-s^-_j \right),
# $$
# where
#
# $$
# s^{\pm}_j = \lbrace -1,1 \rbrace.
# $$

# %% [markdown]
# ### Return-risk function

# %% [markdown]
# $$
# \begin{align}
# C_{RR}({\bf z}) &= -\sum_k (1-\lambda) r_k z_k + \lambda\sum_{kj} \sigma_{kj} z_k z_j, \\
#  &= -\sum_k \frac{ (1-\lambda)}{2} r_k\left( s^+_k-s^-_k\right) + \frac{\lambda}{4}\sum_{kj} \sigma_{kj} \left( s^+_k-s^-_k\right) \left( s^+_j-s^-_j\right),
# \end{align}
# $$

# %% [markdown]
# ### Soft constraint encoding

# %% [markdown]
# $$
# \begin{align}
# P_{\rm INV}(z) &= A\left(\sum_j z_j-D\right)^2\\
# &= A\left(\sum_{jk} z_k z_j-2D\sum_j z_j+D^2 \right)\\
# &= \sum_{kj} \frac{A}{4} \left( s^+_k s^+_j-s^+_k s^-_j - s^-_k s^+_j+ s^-_k s^-_j \right) -AD\sum_{j} (s^+_j-s^-_j)+AD^2
# \end{align}
# $$
#
#
# The simple method of choosing the the penalty scaling coefficient $A$ is to choose
#
# $$
# A > \text{max}\lbrace C_{RR}({\bf s})+C_{TC}({\bf s}) \rbrace-\text{min}\lbrace C_{RR}({\bf s})+C_{TC}({\bf s}) \rbrace
# $$

# %% [markdown]
# ### Transaction cost encoding

# %% [markdown]
# To encode the transcation cost, we factorize the discrete Dirac-delta function as
#
# $$
# \delta(z-y) = c_0(z-y-2)(z-y-1)(z-y+1)(z-y+2),
# $$
#
# where $z,y \in \lbrace -1,0,1 \rbrace$ noting that $\delta(z-y) =0$ except when $z=y$, where $\delta(z-y) =1$. This implies that
#
# $$
# \begin{align}
# \delta(z-y) &= \frac{1}{4}(z-y-2)(z-y-1)(z-y+1)(z-y+2),\\
# &= \left(\frac{3}{2}y^2-1 \right)z^2+(1-y^2)+\frac{1}{2}yz.
# \end{align}
# $$
#
# and so,
#
# $$
# \begin{align}
# C_{TS}(s_i) &= T(1 - \delta(s_i-y_i) ),\\
# &= T \left(1-\left(\frac{3}{2}y^2-1 \right)z^2-(1-y^2)-\frac{1}{2}yz \right),\\
# &= T \left(-\frac{1}{2}\left(\frac{3}{2}y^2-1 \right)(1-s^+_is^-_i)-y^2-\frac{1}{4}y(s^+_i- s^-_i). \right)
# \end{align}
# $$
#
# This last function generates all of the correct combinations except for $(y_i,s_i^+,s_i^-)=(0,1,1)$. There we would like this function to generate the value $T$ instead of $0$. To carry this out, we will add a function $g(s_i)$ that is zero for $y^2_i=1$ and for  $y_i,s_i^+,s_i^- = (0,-1,-1),(0,-1,1),(0,-1,1)$. Furthermore,$g(s^+_i,s^-_i)=T$. This function is easily found to be
#
# $$
# g(s_i) = \frac{T}{4}\left(1+s^+_i s^-_i +s^-_i +s^+_i \right)(1-y^2_i).
# $$
#
#
# Adding this additional peanlization term, we arrive at the cost-function encoding
#
# $$
# \begin{align}
# C_{TS}(s_i) = \frac{1}{4}T\left( 3+(1-y^2_i-y_i)s^{+}_{i}+(1-y^2_i+y_i)s^{-}_{i}+(2y^2_i-1)s^{+}_{i}s^{-}_{i} \right)
# \end{align}
# $$

# %%
# Here we verify that this cost function reproduces all values in the paper 
# by M. Hodson 2019


def C_stored(sm,sp,y):
    '''
    The Tabulated values, (T=1)
    for Table II of Hodson et. al. 2019
    '''
    
    sm = int((sm+1)/2)
    sp = int((sp+1)/2)
    y = y+1
    
    A = np.zeros((3,2,2))
    A[0,0,0]=1
    A[0,0,1]=1
    A[0,1,0]=0
    A[0,1,1]=1
    
    A[1,0,0]=0
    A[1,0,1]=1
    A[1,1,0]=1
    A[1,1,1]=1
    
    A[2,0,0]=1
    A[2,0,1]=0
    A[2,1,0]=1
    A[2,1,1]=1
    
    return A[y,sm,sp]

def C_TC(sm,sp,y):
    '''
    C_{TC}(s,y) function
    
    sm -> s^-_k
    sp -> s^+_k
    
    where:
    sm: {-1,1}
    sp: {-1,1}
    '''
    return 1/4*(3+(1-y**2-y)*sp+(1-y**2+y)*sm+(2*y**2-1)*sp*sm)

# Enumerate all possible input combinations
y_index = [-1,0,1]
sp_index = [-1,1]
sm_index = [-1,1]
combinations = itertools.product(y_index,sp_index,sm_index)

for y,sp,sm in list(combinations):
    print('Function input values: y={}, s^+_k={}, s^-_k={}'.format(y,sp,sm))
    print('Cost function value: {}'.format(C_TC(sm,sp,y))) 
    print('Stored value: {}'.format(C_stored(sm,sp,y)))
    print('')
# Out:
# Function input values: y=-1, s^+_k=-1, s^-_k=-1
# Cost function value: 1.0
# Stored value: 1.0
#
# Function input values: y=-1, s^+_k=-1, s^-_k=1
# Cost function value: 0.0
# Stored value: 0.0
#
# Function input values: y=-1, s^+_k=1, s^-_k=-1
# Cost function value: 1.0
# Stored value: 1.0
#
# Function input values: y=-1, s^+_k=1, s^-_k=1
# Cost function value: 1.0
# Stored value: 1.0
#
# Function input values: y=0, s^+_k=-1, s^-_k=-1
# Cost function value: 0.0
# Stored value: 0.0
#
# Function input values: y=0, s^+_k=-1, s^-_k=1
# Cost function value: 1.0
# Stored value: 1.0
#
# Function input values: y=0, s^+_k=1, s^-_k=-1
# Cost function value: 1.0
# Stored value: 1.0
#
# Function input values: y=0, s^+_k=1, s^-_k=1
# Cost function value: 1.0
# Stored value: 1.0
#
# Function input values: y=1, s^+_k=-1, s^-_k=-1
# Cost function value: 1.0
# Stored value: 1.0
#
# Function input values: y=1, s^+_k=-1, s^-_k=1
# Cost function value: 1.0
# Stored value: 1.0
#
# Function input values: y=1, s^+_k=1, s^-_k=-1
# Cost function value: 0.0
# Stored value: 0.0
#
# Function input values: y=1, s^+_k=1, s^-_k=1
# Cost function value: 1.0
# Stored value: 1.0

# %%
# %load_ext autoreload
# %autoreload 2

import qc_utils as utils
import cirq
from cirq.contrib.svg import SVGCircuit
import matplotlib.pyplot as plt
import sympy
import itertools
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Construct the QAOA circuit

# %%
# Define the number of portfolios to optimize
N_portfolio = 4

# Instantiate the portfolio 
portfolio1 = utils.Portfolio(N_portfolio=N_portfolio)

# Generate a QAOA circuit with p=1 depth
QAOA_circuit = portfolio1.QAOA_circuit(p=1)

# plot the circuit
SVGCircuit(QAOA_circuit)

# %%
# Get the benchmark parameters
benchmark_parameters = portfolio1.benchmark_values()

# %%
# Determine the results via a bruteforce search
best_bruteforce_result = portfolio1.brute_force_search(benchmark_parameters)

# %%
# Determine the p=1 energy landscape for the QAOA 
QAOA_results = portfolio1.grid_search(QAOA_circuit,N_grid=20,parameters=benchmark_parameters,n_trials=100)

penalty_cost_grid = QAOA_results['penalty_cost_grid']
best_holdings = QAOA_results['min_portfolio_holdings']

# %%
plt.figure(figsize=(10,10))
plt.imshow(penalty_cost_grid)
plt.xticks([0,1])
plt.colorbar()
plt.show()

# %%
# Show the c
plt.figure(figsize=(15,5))
plt.bar(np.arange(len(QAOA_results['min_portfolio_holdings']['labels'])), QAOA_results['min_portfolio_holdings']['counts'], tick_label=QAOA_results['min_portfolio_holdings']['labels'])
plt.xticks(rotation=90)
plt.show()

# %%
best_QAOA_result = portfolio1.determine_best_solution_from_trials(benchmark_parameters,best_holdings)

# %%
# Generate a QAOA circuit with p=1 depth
QAOA_circuit_p = portfolio1.QAOA_circuit(p=2)

# Optimize the circuit using Scipy-optimizer
optimization_results = portfolio1.optimize_circuit(circuit=QAOA_circuit_p,parameters=benchmark_parameters,n_trials=100,p=2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-75b960b18fcb> in <module>
#       3
#       4 # Optimize the circuit using Scipy-optimizer
# ----> 5 optimization_results = portfolio1.optimize_circuit(circuit=QAOA_circuit_p,parameters=benchmark_parameters,n_trials=100,p=2)
#
# ~/Documents/qc_mentorship_project/qc_utils.py in optimize_circuit(self, circuit, parameters, n_trials, p)
#     746
#     747         x0 = np.random.rand(2*p)
# --> 748         res = minimize(self.circuit_measurement_function, x0,
#     749                        args =(circuit,parameters,n_trials,p),
#     750                        method='nelder-mead',
#
# ~/Documents/qc_mentorship_project/venv/lib/python3.8/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     596
#     597     if meth == 'nelder-mead':
# --> 598         return _minimize_neldermead(fun, x0, args, callback, **options)
#     599     elif meth == 'powell':
#     600         return _minimize_powell(fun, x0, args, callback, **options)
#
# ~/Documents/qc_mentorship_project/venv/lib/python3.8/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     600         xbar = numpy.add.reduce(sim[:-1], 0) / N
#     601         xr = (1 + rho) * xbar - rho * sim[-1]
# --> 602         fxr = func(xr)
#     603         doshrink = 0
#     604
#
# ~/Documents/qc_mentorship_project/venv/lib/python3.8/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# ~/Documents/qc_mentorship_project/qc_utils.py in circuit_measurement_function(self, x, circuit, parameters, n_trials, p)
#     733         gammas = x[0:p]
#     734         betas = x[p:]
# --> 735         bitstrings = self.measure_circuit(circuit, parameters=parameters, betas=betas, gammas=gammas, n_trials=n_trials)
#     736         portfolio_holdings = self.convert_bitstrings_to_portfolio_holdings(bitstrings)
#     737         energy_expectation_value = self.compute_total_cost_expectation_value(portfolio_holdings, parameters)
#
# ~/Documents/qc_mentorship_project/qc_utils.py in measure_circuit(self, circuit, parameters, betas, gammas, key, n_trials)
#     515
#     516         # Carry out the n_trial measurements
# --> 517         results = simulator.run(circuit,resolver,repetitions=n_trials)
#     518
#     519         # Extract the bitstrings that were measured
#
# ~/Documents/qc_mentorship_project/venv/lib/python3.8/site-packages/cirq/work/sampler.py in run(self, program, param_resolver, repetitions)
#      47             TrialResult for a run.
#      48         """
# ---> 49         return self.run_sweep(program, study.ParamResolver(param_resolver),
#      50                               repetitions)[0]
#      51
#
# ~/Documents/qc_mentorship_project/venv/lib/python3.8/site-packages/cirq/sim/simulator.py in run_sweep(self, program, params, repetitions)
#      79             raise ValueError("Circuit has no measurements to sample.")
#      80
# ---> 81         _verify_unique_measurement_keys(program)
#      82
#      83         trial_results = []  # type: List[study.TrialResult]
#
# ~/Documents/qc_mentorship_project/venv/lib/python3.8/site-packages/cirq/sim/simulator.py in _verify_unique_measurement_keys(circuit)
#     579
#     580 def _verify_unique_measurement_keys(circuit: circuits.Circuit):
# --> 581     result = collections.Counter(
#     582         protocols.measurement_key(op, default=None)
#     583         for op in ops.flatten_op_tree(iter(circuit)))
#
# ~/Documents/qc_mentorship_project/venv/lib/python3.8/collections/__init__.py in __init__(self, iterable, **kwds)
#     550         '''
#     551         super(Counter, self).__init__()
# --> 552         self.update(iterable, **kwds)
#     553
#     554     def __missing__(self, key):
#
# ~/Documents/qc_mentorship_project/venv/lib/python3.8/collections/__init__.py in update(self, iterable, **kwds)
#     635                     super(Counter, self).update(iterable) # fast path when counter is empty
#     636             else:
# --> 637                 _count_elements(self, iterable)
#     638         if kwds:
#     639             self.update(kwds)
#
# ~/Documents/qc_mentorship_project/venv/lib/python3.8/site-packages/cirq/sim/simulator.py in <genexpr>(.0)
#     579
#     580 def _verify_unique_measurement_keys(circuit: circuits.Circuit):
# --> 581     result = collections.Counter(
#     582         protocols.measurement_key(op, default=None)
#     583         for op in ops.flatten_op_tree(iter(circuit)))
#
# ~/Documents/qc_mentorship_project/venv/lib/python3.8/site-packages/cirq/ops/op_tree.py in flatten_to_ops(root)
#     104     elif isinstance(root, Iterable) and not isinstance(root, str):
#     105         for subtree in root:
# --> 106             yield from flatten_to_ops(subtree)
#     107     else:
#     108         _bad_op_tree(root)
#
# ~/Documents/qc_mentorship_project/venv/lib/python3.8/site-packages/cirq/ops/op_tree.py in flatten_to_ops(root)
#     104     elif isinstance(root, Iterable) and not isinstance(root, str):
#     105         for subtree in root:
# --> 106             yield from flatten_to_ops(subtree)
#     107     else:
#     108         _bad_op_tree(root)
#
# ~/Documents/qc_mentorship_project/venv/lib/python3.8/site-packages/cirq/ops/op_tree.py in flatten_to_ops(root)
#     100         TypeError: root isn't a valid OP_TREE.
#     101     """
# --> 102     if isinstance(root, Operation):
#     103         yield root
#     104     elif isinstance(root, Iterable) and not isinstance(root, str):
#
# KeyboardInterrupt:

# %%
print(best_QAOA_result['minimum_cost_states'])
print(best_bruteforce_result['minimum_cost_states'])
print(optimization_results['best_solutions']['minimum_cost_states'])
# Out:
# [[1 0 1 0]]
# [[1 0 1 0]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-74e2e6c328b0> in <module>
#       1 print(best_QAOA_result['minimum_cost_states'])
#       2 print(best_bruteforce_result['minimum_cost_states'])
# ----> 3 print(optimization_results['best_solutions']['minimum_cost_states'])
#
# NameError: name 'optimization_results' is not defined

# %%
# Generate a QAOA circuit with p=1 depth
QAOA_circuit_p = portfolio1.QAOA_circuit(p=1)

# 
angle_means,angle_covariance =portfolio1.optimize_circuit_angles_cross_entropy(QAOA_circuit_p,
                                                              benchmark_parameters,
                                                              p=1,
                                                              n_trials=20,
                                                              iterations=5,
                                                              f_elite=0.2,
                                                              Nce_samples = 50)
# Out:
# 0 0.09750340354999998 0.026572636496984978
# 1 0.05791795375000001 0.0116369309543694
# 2 0.042054621599999994 0.006600129191036496
# 3 0.04009702705 0.006132880414461603
# 4 0.03245114585 0.0033607585717310377

# %%
# With the optimal angle, now run the circuit
betas = angle_means[0:1]
gammas = angle_means[1:]
n_trials = 100
bitstrings = portfolio1.measure_circuit(QAOA_circuit_p, parameters=benchmark_parameters, betas=betas, gammas=gammas, n_trials=n_trials)
portfolio_holdings =portfolio1.convert_bitstrings_to_portfolio_holdings(bitstrings)

plt.figure(figsize=(15,5))
plt.bar(np.arange(len(portfolio_holdings['labels'])), portfolio_holdings['counts'], tick_label=portfolio_holdings['labels'])
plt.xticks(rotation=90)
plt.show()

# %%
print(best_bruteforce_result['minimum_cost_states'])
#print(best_bruteforce_result['minimum_cost'])
#print(optimization_results['optimal_energy_measurement'])
# Out:
# [[1 0 1 0]]

# %% [markdown]
# # Construct the AOA Circuit

# %%
# Define the number of portfolios to optimize
N_portfolio = 4

# Instantiate the portfolio 
portfolio1 = utils.Portfolio(N_portfolio=N_portfolio)

# Generate a QAOA circuit with p=1 depth
QAOA_circuit = portfolio1.AOA_circuit(p=1,D=1)

# plot the circuit
SVGCircuit(QAOA_circuit)
